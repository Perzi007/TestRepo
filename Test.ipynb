# %% [markdown]
# # Test Notebook
#
# This is a sample Jupyter Notebook created for the GitHub Hands-on Lab (Open Source Tools for Data Science).

# %%
print("Hello, World!")

# %%
# Simple calculation example
a = 5
b = 3
print("Sum:", a + b)
